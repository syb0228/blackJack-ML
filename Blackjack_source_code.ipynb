# %% [markdown]
# <a href="https://colab.research.google.com/github/syb0228/blackJack-RL/blob/main/Blackjack_source_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BlackJack : Monte-Carlo with Exploring Start
# ----
#
# ## 설명
# 블랙잭 게임에서의 최적 Policy를 찾는 프로그램입니다. 본 프로그램에서 정의된 블랙잭 룰은 다음과 같습니다.
#  - 하나의 카드 덱(조커를 제외한 52장의 카드)을 사용
#  - 카드의 합을 계산할 시 A = 1 or 11, J,Q,K = 10으로 계산
#  - 플레이어는 Hit 또는 Stick만을 할 수 있음
#  - 카드의 합이 21 이하일 경우, 딜러와 플레이어 중 숫자가 더 높은 쪽이 승리.
#  - 카드의 합이 21 초과한 딜러/플레이어는 패배
#  - 카드의 합이 같을 경우 무승부
#
# 본 프로그램에서는 최적 Policy를 찾기 위해 Monte-Carlo Control with Exploring Start[1] 알고리즘을 사용합니다. 최적 Policy를 찾기 위해, 본 프로그램은 다음과 같은 변수로 구성된 State로부터 탐색을 수행합니다.
#  - 플레이어 카드의 합 : 12 ~ 21 사이의 정수
#  - 딜러가 보여주는 카드의 숫자 : 1 ~ 10 사이의 정수
#  - 플레이어가 현재 사용 가능한 Ace의 유무 : True / False
#
# 위와 같이 구성된 State S에서 Action A를 선택했을 때의 기대 리턴(게임이 끝났을 때 얻을 것으로 기대되는 보상의 합)은 Q(S,A)입니다. 많은 에피소드를 경험할수혹 Agent는 Optimal Q(S,A)에 가까운 값을 학습하게 되며, 이로부터 최적 Policy를 찾을 수 있습니다.
#
# ----
#
# ## 0. Package
# 먼저 본 프로그램에서 사용할 Package를 Import합니다.

# %%
# %matplotlib inline
import random
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib import colors

# %% [markdown]
# ## 1. Class : Deck
# 카드 덱 한 벌에 해당하는 클래스를 선언합니다. 조커를 제외한 52장의 카드로 이루어져 있으며, 각 카드는 정수로 표기됩니다. <br>
# A = 11, J, Q, K = 10으로 표현되며, 나머지 카드는 해당 카드에 적힌 숫자만큼의 값을 갖습니다.
#
# ### 클래스 구성
# * Attributes
#    * card_deck : List, 52개의 정수로 이루어짐
# * Methods
#    * shuffle() : 카드 덱을 랜덤하게 섞음
#    * draw() : 카드 덱에서 한 장을 뽑아 리턴
#    * reset() : 카드 덱을 초기화함

# %%
class Deck(object):
    """
    Deck : Card deck, which can be shuffled, drawn, and reset.
    """

    def __init__(self):
        deck = [2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10, 11]
        self.card_deck = deck * 4
        self.shuffle()

    def shuffle(self):
        random.shuffle(self.card_deck)

    def draw(self):
        return self.card_deck.pop()

    def reset(self):
        deck = [2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10, 11]
        self.card_deck = deck * 4
        self.shuffle()

# %% [markdown]
# ## 2. Class : Dealer
# 다음으로 Dealer 클래스를 선언합니다.<br>
# Dealer 클래스는 강화학습에서의 Environment에 해당합니다. 플레이어의 Action을 받고, 그에 따른 다음 State와 Reward를 반환합니다.<br>
# 딜러는 시작할 때 두 장의 카드를 받습니다. 플레이어의 차례가 끝난 후, 플레이어의 카드 합이 21을 넘지 않는다면 딜러는 다음과 같이 행동합니다.
#  - 딜러 카드의 합이 17 미만일 때 : 카드 한 장을 추가로 뽑음 (Hit)
#  - 딜러 카드의 합이 17 이상일 때 : 플레이어의 카드 합과 비교하여 승패 결정 (Stick)
#
# ### 클래스 구성
# 딜러 클래스는 다음과 같이 구성됩니다
#  - Attributes
#      - hands : List, 딜러가 가지고 있는 카드들
#      - usable_ace : List, 딜러가 가지고 있는 A의 인덱스
#  - Methods
#      - hit(deck) : 카드 덱에서 카드 한 장을 뽑아 hands에 추가
#      - show() : 딜러가 가진 카드 중 랜덤한 한 장의 값을 리턴
#      - calculate_sum() : 딜러가 가진 카드의 합을 리턴. 카드 합이 21 이상일 때 사용 가능한 Ace가 있다면 사용함.
#      - action() : 딜러의 Action - 합이 17 미만이면 hit, 이상이면 stick
#      - observation(action, agent, deck) : 플레이어의 action을 받아 종료 여부와 reward 리턴
#      - calculate_rewards(agent, deck) : 플레이어와 딜러의 승패 계산 및 reward 리턴
#      - reset() : 딜러 클래스의 모든 attribute 초기화

# %%
class Dealer(object):
    """
    Dealer : 딜러 클래스
    딜러는 두 장의 카드를 받고, 카드의 합이 16 이하이면 Hit, 17이상이면 Stick 함.
    처음 두 장을 받았을 때 한 장의 카드를 랜덤하게 오픈함.
    """

    def __init__(self):
        """
        hand : 딜러가 가진 카드
        usable_ace : 딜러가 가진 카드 리스트 중 ace의 인덱스
        natural : 두 장의 카드로 21이 되면 True, 아니면 False
        """
        self.hands = list()
        self.usable_ace = list()

    def hit(self, deck: Deck):
        """
        딜러의 Hit. 새로운 카드가 Ace라면 사용 가능한 Ace 리스트에 추가함
        :param deck: Deck Object
        :return:
        """
        new_card = deck.draw()
        if new_card == 11:
            self.usable_ace.append(len(self.hands))
        self.hands.append(new_card)

    def show(self):
        """
        딜러가 가진 카드 중 하나를 랜덤하게 보여줌
        :return: 딜러의 카드 중 랜덤한 카드 숫자
        """
        card = random.choice(self.hands)
        if card == 11:
            card = 1
        return card

    def calculate_sum(self):
        """
        딜러가 가진 카드의 합을 구함
        21을 넘을 때 사용 가능한 Ace가 있으면 사용함
        :return: 딜러 카드의 합
        """
        sums = sum(self.hands)
        if sums > 21 and len(self.usable_ace) > 0:
            self.hands[self.usable_ace.pop()] = 1
            sums = sum(self.hands)
        return sums

    def action(self, deck: Deck):
        """
        딜러의 순서 때 딜러의 행동.
        숫자의 합이 16 이하일 때는 Hit, 17 이상이면 Stick
        :param deck:
        :return:
        """
        while True:
            sums = self.calculate_sum()
            if sums < 17:
                self.hit(deck)
            else:
                return sums

    def observation(self, action, agent, deck):
        """
        플레이어의 Action을 받아, 그에 맞는 Observation과 Reward를 반환
        :param action: agent 의 Action
        :param agent: agent 클래스
        :param deck: deck 클래스
        :return: 에피소드 종료 여부, reward
        """
        done = False
        reward = 0
        if action == True:  # Hit
            agent.hit(deck)
            if agent.calculate_sum() > 21:  #플레이어의 Hit으로 인해 카드 합이 21이 넘으면 즉시 종료
                done = True
                reward = -1
        else:  # Stick
            done = True
            reward = self.calcuate_reward(agent, deck)

        return done, reward

    def calcuate_reward(self, agent, deck):
        """
        플레이어가 Stick했을 때 딜러와의 카드 비교 수행
        :param agent:
        :param deck:
        :return: Reward
        """
        agent_sum = agent.calculate_sum()           # 플레이어의 카드 합 계산
        if agent_sum > 21:                          # 플레이어의 Bust (패)
            return -1

        dealer_sum = self.action(deck)              # 딜러의 카드 합 계산
        if dealer_sum > 21:                         # 딜러가 Bust (승)
            return 1
        if dealer_sum > agent_sum:                  # 딜러의 카드 합 > 플레이어 합 (패)
            return -1
        if dealer_sum < agent_sum:                  # 딜러의 카드 합 < 플레이어 합 (승)
            return 1
        return 0                                   # 딜러의 카드 합 == 플레이어의 합 (무)

    def reset(self):
        """
        딜러 초기화 (새로운 에피소드 시작을 위해)
        """
        self.hands = list()
        self.usable_ace = list()

    def counting_card(self):
        count = len(self.hands)
        return count

    def kind(self):
        kind_count = Counter(self.hands)
        print(kind_count)

# %% [markdown]
# ## 3. Class : Agent
# Agent 클래스는 플레이어에 해당하며, 최적 Policy를 학습하는 주체가 됩니다. Agent는 여러 에피소드들로부터 Q값(기대 Return)을 계산하고, 다음 에피소드 수행 시 해당 State에서 Q값이 높은 Action을 선택하는 Greedy Policy를 따릅니다.
#
# ### 클래스 구성
#
# Agent의 구성은 다음과 같습니다.
#
#  - Attributes
#      - hands : List, Agent가 가지고 있는 카드들
#      - usable_ace : List, Agent가 가지고 있는 A의 인덱스
#      - Q_table : Dictionary, 기대 Return값과 방문 횟수를 저장
#  - Methods
#      - hit(deck) : 카드 덱에서 카드 한 장을 뽑아 hands에 추가
#      - calculate_sum() : Agent가 가진 카드의 합을 리턴. 카드 합이 21 이상일 때 사용 가능한 Ace가 있다면 사용함.
#      - random_action() : 현재 State에 상관없이 랜덤하게 Action을 리턴
#      - policy(state) : 현재 State에서 가능한 Action 중, Q_table의 값이 큰 Action을 리턴
#      - update_qval(episode) : 에피소드로부터 평균 리턴을 계산하여 Q_table을 업데이트
#      - reset() : Agent 클래스의 모든 attribute 초기화

# %%
class Agent(object):
    def __init__(self):
        """
        hand : 플레이어의 카드
        usable_ace : 사용 가능한 ace 리스트
        Q_table : q(s,a) 값을 저장할 딕셔너리
        """
        self.hands = list()
        self.usable_ace = list()
        self.Q_table = dict()

    def hit(self, deck: Deck):
        """
        덱에서 새로운 카드를 뽑음
        :param deck: Deck for draw a card
        :return: None
        """
        new_card = deck.draw()
        if new_card == 11:
            self.usable_ace.append(len(self.hands))
        self.hands.append(new_card)

    def calculate_sum(self):
        """
        플레이어가 가진 카드의 합을 구함.
        21을 넘을 때 사용 가능한 ace가 있으면 사용함
        :return:
        """
        sums = sum(self.hands)
        if sums > 21 and len(self.usable_ace) > 0:
            self.hands[self.usable_ace.pop()] = 1
            sums = sum(self.hands)
        return sums

    def random_action(self):
        """
        랜덤하게 행동
        True = hit, False = stick
        :return:
        """
        return random.choice([True, False])

    def policy(self, state):
        """
        Agent의 policy 함수.
        e의 확률로 랜덤 행동을 하며, 그 외에는 현재 state에서 큰 q(s,a)값을 갖는 action을 선택함
        :param state: Agent에게 주어진 state
        :return: agent의 action을 반환 , True = hit and False = stick
        """
        # Q_table에서 현재 state-action에 대해 값이 존재하는지 검사함
        for action in (True, False):
            if (state, action) not in self.Q_table.keys():  # Q_table에 값이 없으면 0으로 초기화
                self.Q_table[(state, action)] = [0, 0]      # (mean return, visit count)
            else:
                continue

        # q값이 큰 action 선택
        if self.Q_table[(state, True)] > self.Q_table[(state, False)]:
            return True     # Hit
        elif self.Q_table[(state, True)] == self.Q_table[(state, False)]:   # q값이 같으면 무작위추출
            return self.random_action()
        else:
            return False    # Stick


    def reset(self):
        """
        Agent를 리셋함
        :return: None
        """
        self.hands = list() 
        self.usable_ace = list()

    def update_qval(self, episode):
        """
        에피소드(한 번의 게임)으로부터 Q_table 을 업데이트함
        Q 테이블에 없는 state-action 쌍이 나오면 새로 생성
        Q 테이블에 state-action 쌍이 존재한다면 Incremental mean 적용하여 업데이트
        :param episode: Episode generated from environment
        :return: None
        """
        total_return = 0
        for state, action, reward in episode[::-1]:     # 에피소드의 뒤에서부터 (역순)
            total_return += reward                       # return Gt 계산
            if (state, action) not in self.Q_table.keys():  # state-action 쌍이 없다면
                self.Q_table[(state, action)] = [total_return, 1]   # 새롭게 엔트리 생성 (Gt, count)

            else:  #이미 존재하는 state-action 쌍이면 Incremental mean 적용
                prev_val = self.Q_table[(state, action)][0]         # 이전의 평균 return
                count = self.Q_table[(state, action)][1] + 1        # count 증가
                mean = prev_val + (total_return - prev_val) / count # 평균 계산 : Incremental Mean 적용
                self.Q_table[(state, action)] = [mean, count]  # 업데이트

    def counting_card(self):
        count = len(self.hands)
        return count

    def kind(self):
        kind_count = Counter(self.hands)
        print(kind_count)

# %% [markdown]
# ## 4. Class : MonteCarlo
# Monte-Carlo control with Exploring Start를 구현한 클래스입니다. 에피소드를 생성할 수 있고, 생성된 에피소드로부터 에이전트를 학습시킵니다.
# 에피소드 생성 시 Exploring Start를 위해 에피소드의 첫 번째 State에서는 무작위로 Action을 선택하며, 이후에는 에이전트의 Policy를 따라 Action을 선택합니다.
#
# ### 클래스 구성
# MonteCarlo 클래스는 다음과 같이 구성됩니다.
#  - Attribute
#      - 없음
#  - Methods
#      - generate_episode(dealer, agent, deck) : 딜러, 플레이어, 카드 덱을 이용해 한 번의 블랙잭 게임을 진행하고 에피소드를 반환합니다.
#      - train(dealer, agent, deck, it, verbose) : 지정된 이터레이션 수만큼의 에피소드로부터 플레이어를 학습시킵니다.

# %%
used_cards = 0 # 사용한 카드 수

class MonteCarlo(object):
    def generate_episode(self, dealer: Dealer, agent: Agent, deck: Deck):
        """
        하나의 에피소드(게임)를 생성함
        :param dealer:
        :param agent:
        :param deck:
        :return:
        """

        global used_cards
        used_cards += agent.counting_card() # agent 카드 수 더하기
        used_cards += dealer.counting_card() # 딜러 카드 수 더하기
        
        if 52 - used_cards < 15 : # 남은 카드가 15장 미만이면
            deck.reset() # 카드 덱 초기화
            used_cards = 0 # 사용한 카드 수 초기화
        
        # 딜러, Agent를 초기화
        dealer.reset()
        agent.reset()
        agent.hit(deck)
        agent.hit(deck)
        dealer.hit(deck)
        dealer.hit(deck)

        done = False    # 에피소드의 종료 여부

        episode = list()    # 에피소드

        while not done:
            # 에피소드가 끝날 때까지 State, Action, Reward를 생성
            sums = agent.calculate_sum()
            if sums < 12:
                agent.hit(deck)
                continue

            state = (sums, bool(agent.usable_ace), dealer.show())

            ########   Exploring Start ~!!!!!!!!! : 
            if len(episode) == 0:       # 첫번째 State 일 때는 무작위 Action 선택
                action =agent.random_action()
            else:                       # 그 외에는 Q 테이블에서 큰 값을 갖는 Action 선택
                action = agent.policy(state)
            
            done, reward = dealer.observation(action, agent, deck)  # 에피소드 종료 여부, Reward 계산
            
            # 생성된 State, Action, Reward를 에피소드에 추가
            episode.append([state, action, reward])

        return episode

    def train(self, dealer: Dealer, agent: Agent, deck: Deck, it=10000, verbose=True):
        count = 0
        win = 0
        loss = 0
        draw = 0
        total_win = 0
        total_loss = 0
        total_draw = 0
        result = str()
        for i in range(it):
            count += 1
            episode = self.generate_episode(dealer, agent, deck)
            agent.update_qval(episode)

            if episode[-1][-1] == 1:
                win += 1
            elif episode[-1][-1] == 0:
                draw += 1
            else:
                loss += 1

            if count % 1000 == 0 and verbose == True:
                total_win += win
                total_loss += loss
                total_draw += draw

                print("========== Training : Episode ", count, " ===========")
                print("Recent 1000 games win rate :{:.3f}%".format(win / (win + loss) * 100))
                print(" -- 1000 Games WIN :", win, "DRAW :", draw, "LOSS :", loss)
                print("Total win rate : {:.3f}%".format(total_win / (total_win + total_loss) * 100))
                print(" -- TOTAL Games WIN :", total_win, "DRAW :", total_draw, "LOSS :", total_loss)

                win = 0
                loss = 0
                draw = 0

# %% [markdown]
# ## 5. Function : plot_q_val(agent, usable_ace)
# Q값을 시각화하기 위한 함수입니다.

# %%
def plot_q_val(agent: Agent, usable_ace=True):
    fig = plt.figure()
    ax = Axes3D(fig)

    hands = set()
    dealer_show = set()

    for state, action in sorted(agent.Q_table.keys()):
        hands.add(state[0])
        dealer_show.add(state[2])

    Z_list = list()

    l = list()

    for d in dealer_show:
        l = []
        for hand in hands:
            if ((hand, usable_ace, d), True) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), True)] = [0, 0]
            if ((hand, usable_ace, d), False) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), False)] = [0, 0]
            v_val = max([agent.Q_table[((hand, usable_ace, d), True)][0], agent.Q_table[((hand, usable_ace, d), False)][0]])
            l.append(v_val)
        Z_list.append(l)

    Y = np.array(list(hands))
    X = np.array(list(dealer_show))
    if usable_ace:
        X, Y = np.meshgrid(X, Y)
    else:
        X, Y = np.meshgrid(X, Y)

    Z = np.array(Z_list).T

    ax.plot_wireframe(X, Y, Z)
    plt.show()

# %% [markdown]
# ## 6. Function : plot_q_val(agent, usable_ace)
# 최적 Policy를 시각화하기 위한 함수입니다.

# %%
def plot_action(agent: Agent, usable_ace=True):
    hands = set()
    dealer_show = set()

    for state, action in sorted(agent.Q_table.keys()):
        hands.add(state[0])
        dealer_show.add(state[2])

    Z_list = list()

    l = list()

    action = False

    for d in dealer_show:
        l = []
        for hand in hands:
            if ((hand, usable_ace, d), True) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), True)] = [0, 0]
            if ((hand, usable_ace, d), False) not in agent.Q_table.keys():
                agent.Q_table[((hand, usable_ace, d), False)] = [0, 0]
            l.append(0 if agent.Q_table[((hand, usable_ace, d), True)][0] > agent.Q_table[((hand, usable_ace, d), False)][0] else 1)
        Z_list.append(l)

    Y = np.array(list(hands))
    X = np.array(list(dealer_show))
    if usable_ace:
        X, Y = np.meshgrid(X, Y)
    else:
        X, Y = np.meshgrid(X, Y)
    Z = np.array(Z_list).T

    data = Z[::-1,:]
    data = np.append(data, [0 for _ in range(Z[0].shape[0])]).reshape(-1,Z[0].shape[0])
    
    cmap=cm.coolwarm
    plt.imshow(data, cmap=cmap, extent=[1,11,11,21])

    plt.show()
    return X, Y, Z

# %% [markdown]
# ## 7. 최적 Policy 학습

# %%
deck = Deck()
dealer = Dealer()
agent = Agent()
mc_es = MonteCarlo()

mc_es.train(dealer, agent, deck, it=1000000)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Recent 1000 games win rate :31.038%
#  -- 1000 Games WIN : 293 DRAW : 56 LOSS : 651
# Total win rate : 31.038%
#  -- TOTAL Games WIN : 293 DRAW : 56 LOSS : 651
# ========== Training : Episode  2000  ===========
# Recent 1000 games win rate :36.864%
#  -- 1000 Games WIN : 348 DRAW : 56 LOSS : 596
# Total win rate : 33.951%
#  -- TOTAL Games WIN : 641 DRAW : 112 LOSS : 1247
# ========== Training : Episode  3000  ===========
# Recent 1000 games win rate :33.021%
#  -- 1000 Games WIN : 317 DRAW : 40 LOSS : 643
# Total win rate : 33.638%
#  -- TOTAL Games WIN : 958 DRAW : 152 LOSS : 1890
# ========== Training : Episode  4000  ===========
# Recent 1000 games win rate :37.124%
#  -- 1000 Games WIN : 346 DRAW : 68 LOSS : 586
# Total win rate : 34.497%
#  -- TOTAL Games WIN : 1304 DRAW : 220 LOSS : 2476
# ========== Training : Episode  5000  ===========
# Recent 1000 games win rate :36.667%
#  -- 1000 Games WIN : 341 DRAW : 70 LOSS : 589
# Total win rate : 34.926%
#  -- TOTAL Games WIN : 1645 DRAW : 290 LOSS : 3065
# ========== Training : Episode  6000  ===========
# Recent 1000 games win rate :36.520%
#  -- 1000 Games WIN : 340 DRAW : 69 LOSS : 591
# Total win rate : 35.189%
#  -- TOTAL Games WIN : 1985 DRAW : 359 LOSS : 3656
# ========== Training : Episode  7000  ===========
# Recent 1000 games win rate :36.986%
#  -- 1000 Games WIN : 351 DRAW : 51 LOSS : 598
# Total win rate : 35.448%
#  -- TOTAL Games WIN : 2336 DRAW : 410 LOSS : 4254
# ========== Training : Episode  8000  ===========
# Recent 1000 games win rate :35.599%
#  -- 1000 Games WIN : 330 DRAW : 73 LOSS : 597
# Total win rate : 35.466%
#  -- TOTAL Games WIN : 2666 DRAW : 483 LOSS : 4851
# ========== Training : Episode  9000  ===========
# Recent 1000 games win rate
# Total win rate : 35.471%
#  -- TOTAL Games WIN : 331488 DRAW : 59466 LOSS : 603046
# ========== Training : Episode  995000  ===========
# Recent 1000 games win rate :33.968%
#  -- 1000 Games WIN : 321 DRAW : 55 LOSS : 624
# Total win rate : 35.469%
#  -- TOTAL Games WIN : 331809 DRAW : 59521 LOSS : 603670
# ========== Training : Episode  996000  ===========
# Recent 1000 games win rate :36.684%
#  -- 1000 Games WIN : 343 DRAW : 65 LOSS : 592
# Total win rate : 35.471%
#  -- TOTAL Games WIN : 332152 DRAW : 59586 LOSS : 604262
# ========== Training : Episode  997000  ===========
# Recent 1000 games win rate :33.510%
#  -- 1000 Games WIN : 316 DRAW : 57 LOSS : 627
# Total win rate : 35.469%
#  -- TOTAL Games WIN : 332468 DRAW : 59643 LOSS : 604889
# ========== Training : Episode  998000  ===========
# Recent 1000 games win rate :35.443%
#  -- 1000 Games WIN : 336 DRAW : 52 LOSS : 612
# Total win rate : 35.469%
#  -- TOTAL Games WIN : 332804 DRAW : 59695 LOSS : 605501
# ========== Training : Episode  999000  ===========
# Recent 1000 games win rate :36.842%
#  -- 1000 Games WIN : 350 DRAW : 50 LOSS : 600
# Total win rate : 35.470%
#  -- TOTAL Games WIN : 333154 DRAW : 59745 LOSS : 606101
# ========== Training : Episode  1000000  ===========
# Recent 1000 games win rate :34.769%
#  -- 1000 Games WIN : 323 DRAW : 71 LOSS : 606
# Total win rate : 35.469%
#  -- TOTAL Games WIN : 333477 DRAW : 59816 LOSS : 606707

# %% [markdown]
# ## 8. 학습 결과 시각화

# %%
print("Q-value with Usable Ace")
plot_q_val(agent, usable_ace=True)
print("Q-value without Usable Ace")
plot_q_val(agent, usable_ace=False)
print("Optimal policy with Usable Ace : (RED : STICK, BLUE : HIT)")
usable_result = plot_action(agent, usable_ace=True)
print("Optimal policy without Usable Ace : (RED : STICK, BLUE : HIT)")
no_usable_result = plot_action(agent, usable_ace=False)
# Out:
# Q-value with Usable Ace
# Q-value without Usable Ace
# Optimal policy with Usable Ace : (RED : STICK, BLUE : HIT)
# Optimal policy without Usable Ace : (RED : STICK, BLUE : HIT)

# %% [markdown]
# ----
# ### 목표
# 위 코드에서 최적 Policy를 학습시킨 Agent를 사용하여, 블랙잭 게임을 시뮬레이션한 뒤 승률을 계산.
#
# ### 초기 설정
#  - 플레이어는 1,000,000번의 에피소드로부터 최적 Policy를 학습
#  - 플레이어의 초기 자금 : 10,000 달러
#  - 플레이어는 게임 참가 시 10 달러를 지불, 결과에 따라 금액을 획득
#      - 승리 시 : 20 달러 획득
#      - 무승부 시 : 10 달러 획득
#      - 패배 시 : 0 달러 획득
#
# ### 요구사항
#  - 플레이어와 딜러가 1,000번의 게임을 진행
#  - 1,000번의 게임 후 플레이어의 승률을 계산
#  - 매 게임 별 플레이어의 소지금 변화를 그래프로 시각화
#
# ### 1,000번의 게임 진행

# %%
import numpy as np
money = 10000 # 초기 자금
have_money = [] # 매 게임 별 플레이어의 소지금 변화 기록

total_win = 0
total_loss = 0
total_draw = 0

for i in range(1000): # 1000번의 게임 진행
    money -= 10 # 게임 참가비 지불
    episode = mc_es.generate_episode(dealer, agent, deck) # 에피소드 반환

    if episode[-1][-1] == 1: # 승리
        total_win += 1 # 카운트 증가
        money += 20 # 20달러 획득
        print("%.fth game : win" %(i+1)) # 게임 결과 출력 
    elif episode[-1][-1] == 0: # 무승부
        total_draw += 1
        money += 10 # 10달러 획득
        print("%.fth game : draw" %(i+1))
    else: # 패배
        total_loss += 1
        money += 0 # 0달러 획득
        print("%.fth game : loss" %(i+1))

    have_money.append(money) # 해당 게임 결과에 따른 소지금 기록
# Out:
# 1th game : win
# 2th game : loss
# 3th game : win
# 4th game : win
# 5th game : loss
# 6th game : loss
# 7th game : loss
# 8th game : loss
# 9th game : loss
# 10th game : loss
# 11th game : win
# 12th game : loss
# 13th game : loss
# 14th game : win
# 15th game : loss
# 16th game : loss
# 17th game : loss
# 18th game : loss
# 19th game : loss
# 20th game : loss
# 21th game : win
# 22th game : loss
# 23th game : loss
# 24th game : loss
# 25th game : draw
# 26th game : win
# 27th game : loss
# 28th game : win
# 29th game : loss
# 30th game : loss
# 31th game : loss
# 32th game : win
# 33th game : loss
# 34th game : win
# 35th game : win
# 36th game : win
# 37th game : loss
# 38th game : loss
# 39th game : loss
# 40th game : win
# 41th game : loss
# 42th game : loss
# 43th game : loss
# 44th game : loss
# 45th game : win
# 46th game : win
# 47th game : loss
# 48th game : loss
# 49th game : loss
# 50th game : loss
# 51th game : loss
# 52th game : loss
# 53th game : loss
# 54th game : draw
# 55th game : loss
# 56th game : loss
# 57th game : draw
# 58th game : win
# 59th game : loss
# 60th game : draw
# 61th game : win
# 62th game : loss
# 63th game : loss
# 64th game : win
# 65th game : win
# 66th game : win
# 67th game : loss
# 68th game : loss
# 69th game : win
# 70th game : loss
# 71th game : loss
# 72th game : win
# 73th game : win
# 74th game : loss
# 75th game : loss
# 76th game : loss
# 77th game : loss
# 78th game : loss
# 79th game : loss
# 80th game : loss
# 81th game : win
# 82th game : loss
# 83th game : loss
# 84th game : loss
# 85th game : win
# 86th game : loss
# 87th game : win
# 88th game : win
# 89th game : draw
# 90th game : win
# 91th game : loss
# 92th game : loss
# 93th game : win
# 94th game : loss
# 95th game : loss
# 96th game : loss
# 97th game : loss
# 98th game : loss
# 99th game : loss
# 100th game : loss
# 101th game : draw
# 102th game : loss
# 103th game : loss
# 104th game : loss
# 105th game : loss
# 106th game : win
# 107th game : win
# 108th game : loss
# 109th game : loss
# 110th game : loss
# 111th game : loss
# 112th game : loss
# 113th game : win
# 114th game : win
# 115th game : draw
# 116th game : loss
# 117th game : loss
# 118th game : loss
# 119th game : loss
# 120th game : loss
# 121th game : loss
# 122th game : loss
# 123th game : loss
# 124th game : loss
# 125th game : loss
# 126th game : win
# 127th game : loss
# 128th game : win
# 129th game : win
# 130th game : loss
# 131th game : loss
# 132th game : loss
# 133th game : loss
# 134th game : win
# 135th game : win
# 136th game : win
# 137th game : draw
# 138th game : loss
# 139th game : win
# 140th game : win
# 141th game : loss
# 142th game : loss
# 143th game : win
# 144th game : win
# 145th game : loss
# 146th game : draw
# 147th game : win
# 148th game : win
# 149th game : draw
# 150th game : win
# 151th game : loss
# 152th game : loss
# 153th game : draw
# 154th game : loss
# 155th game : loss
# 156th game : loss
# 157th game : loss
# 158th game : draw
# 159th game : win
# 160th game : loss
# 161th game : loss
# 162th game : win
# 163th game : loss
# 164th game : win
# 165th game : win
# 166th game : loss
# 167th game : loss
# 168th game : win
# 169th game : loss
# 170th game : loss
# 171th game : loss
# 172th game : win
# 173th game : loss
# 174th game : win
# 175th game : loss
# 176th game : loss
# 177th game : loss
# 178th game : loss
# 179th game : loss
# 180th game : loss
# 181th game : win
# 182th game : loss
# 183th game : loss
# 184th game : loss
# 185th game : loss
# 186th game : loss
# 187th game : loss
# 188th game : loss
# 189th game : win
# 190th game : loss
# 191th game : draw
# 192th game : win
# 193th game : loss
# 194th game : win
# 195th game : win
# 196th game : win
# 197th game : loss
# 198th game : loss
# 199th game : win
# 200th game : loss
# 201th game : loss
# 202th game : loss
# 203th game : win
# 204th game : loss
# 205th game : loss
# 206th game : loss
# 207th game : loss
# 208th game : loss
# 209th game : loss
# 210th game : loss
# 211th game : win
# 212th game : win
# 213th game : draw
# 214th game : loss
# 215th game : win
# 216th game : win
# 217th game : win
# 218th game : loss
# 219th game : win
# 220th game : loss
# 221th game : loss
# 222th game : draw
# 223th game : loss
# 224th game : loss
# 225th game : loss
# 226th game : loss
# 227th game : loss
# 228th game : loss
# 229th game : loss
# 230th game : win
# 231th game : loss
# 232th game : loss
# 233th game : win
# 234th game : loss
# 235th game : win
# 236th game : loss
# 237th game : loss
# 238th game : win
# 239th game : loss
# 240th game : loss
# 241th game : loss
# 242th game : loss
# 243th game : loss
# 244th game : win
# 245th game : win
# 246th game : win
# 247th game : loss
# 248th game : loss
# 249th game : loss
# 250th game : draw
# 251th game : loss
# 252th game : loss
# 253th game : draw
# 254th game : loss
# 255th game : loss
# 256th game : win
# 257th game : loss
# 258th game : win
# 259th game : loss
# 260th game : loss
# 261th game : loss
# 262th game : draw
# 263th game : win
# 264th game : win
# 265th game : loss
# 266th game : loss
# 267th game : win
# 268th game : draw
# 269th game : loss
# 270th game : loss
# 271th game : win
# 272th game : loss
# 273th game : win
# 274th game : draw
# 275th game : win
# 276th game : win
# 277th game : loss
# 278th game : loss
# 279th game : win
# 280th game : win
# 281th game : win
# 282th game : loss
# 283th game : win
# 284th game : loss
# 285th game : loss
# 286th game : win
# 287th game : loss
# 288th game : loss
# 289th game : loss
# 290th game : loss
# 291th game : loss
# 292th game : draw
# 293th game : win
# 294th game : loss
# 295th game : loss
# 296th game : loss
# 297th game : win
# 298th game : loss
# 299th game : loss
# 300th game : loss
# 301th game : loss
# 302th game : loss
# 303th game : win
# 304th game : loss
# 305th game : draw
# 306th game : loss
# 307th game : win
# 308th game : loss
# 309th game : loss
# 310th game : loss
# 311th game : win
# 312th game : draw
# 313th game : loss
# 314th game : loss
# 315th game : draw
# 316th game : loss
# 317th game : win
# 318th game : loss
# 319th game : win
# 320th game : loss
# 321th game : loss
# 322th game : win
# 323th game : loss
# 324th game : loss
# 325th game : loss
# 326th game : win
# 327th game : loss
# 328th game : loss
# 329th game : win
# 330th game : loss
# 331th game : loss
# 332th game : win
# 333th game : loss
# 334th game : win
# 335th game : loss
# 336th game : loss
# 337th game : win
# 338th game : win
# 339th game : loss
# 340th game : loss
# 341th game : loss
# 342th game : loss
# 343th game : loss
# 344th game : loss
# 345th game : loss
# 346th game : loss
# 347th game : win
# 348th game : win
# 349th game : loss
# 350th game : loss
# 351th game : win
# 352th game : loss
# 353th game : loss
# 354th game : win
# 355th game : win
# 356th game : loss
# 357th game : loss
# 358th game : loss
# 359th game : win
# 360th game : loss
# 361th game : loss
# 362th game : loss
# 363th game : loss
# 364th game : win
# 365th game : loss
# 366th game : loss
# 367th game : loss
# 368th game : loss
# 369th game : loss
# 370th game : win
# 371th game : win
# 372th game : loss
# 373th game : loss
# 374th game : loss
# 375th game : loss
# 376th game : win
# 377th game : loss
# 378th game : win
# 379th game : loss
# 380th game : loss
# 381th game : win
# 382th game : win
# 383th game : win
# 384th game : win
# 385th game : loss
# 386th game : loss
# 387th game : loss
# 388th game : loss
# 389th game : win
# 390th game : win
# 391th game : loss
# 392th game : loss
# 393th game : win
# 394th game : loss
# 395th game : win
# 396th game : loss
# 397th game : loss
# 398th game : loss
# 399th game : loss
# 400th game : loss
# 401th game : loss
# 402th game : loss
# 403th game : loss
# 404th game : win
# 405th game : loss
# 406th game : loss
# 407th game : loss
# 408th game : loss
# 409th game : win
# 410th game : win
# 411th game : win
# 412th game : loss
# 413th game : win
# 414th game : loss
# 415th game : loss
# 416th game : win
# 417th game : loss
# 418th game : loss
# 419th game : loss
# 420th game : loss
# 421th game : win
# 422th game : win
# 423th game : loss
# 424th game : loss
# 425th game : loss
# 426th game : loss
# 427th game : win
# 428th game : win
# 429th game : win
# 430th game : win
# 431th game : draw
# 432th game : win
# 433th game : win
# 434th game : win
# 435th game : loss
# 436th game : loss
# 437th game : win
# 438th game : loss
# 439th game : loss
# 440th game : loss
# 441th game : loss
# 442th game : draw
# 443th game : win
# 444th game : loss
# 445th game : loss
# 446th game : loss
# 447th game : loss
# 448th game : loss
# 449th game : win
# 450th game : loss
# 451th game : loss
# 452th game : loss
# 453th game : loss
# 454th game : loss
# 455th game : win
# 456th game : loss
# 457th game : win
# 458th game : loss
# 459th game : win
# 460th game : win
# 461th game : win
# 462th game : win
# 463th game : loss
# 464th game : loss
# 465th game : loss
# 466th game : win
# 467th game : loss
# 468th game : loss
# 469th game : draw
# 470th game : loss
# 471th game : loss
# 472th game : loss
# 473th game : win
# 474th game : loss
# 475th game : loss
# 476th game : loss
# 477th game : win
# 478th game : loss
# 479th game : loss
# 480th game : loss
# 481th game : win
# 482th game : win
# 483th game : draw
# 484th game : loss
# 485th game : win
# 486th game : loss
# 487th game : win
# 488th game : loss
# 489th game : loss
# 490th game : win
# 491th game : draw
# 492th game : win
# 493th game : win
# 494th game : loss
# 495th game : draw
# 496th game : win
# 497th game : loss
# 498th game : loss
# 499th game : draw
# 500th game : loss
# 501th game : win
# 502th game : loss
# 503th game : win
# 504th game : loss
# 505th game : loss
# 506th game : loss
# 507th game : loss
# 508th game : loss
# 509th game : win
# 510th game : loss
# 511th game : loss
# 512th game : loss
# 513th game : loss
# 514th game : loss
# 515th game : loss
# 516th game : win
# 517th game : loss
# 518th game : loss
# 519th game : loss
# 520th game : win
# 521th game : loss
# 522th game : draw
# 523th game : loss
# 524th game : loss
# 525th game : loss
# 526th game : loss
# 527th game : win
# 528th game : win
# 529th game : loss
# 530th game : loss
# 531th game : loss
# 532th game : win
# 533th game : loss
# 534th game : loss
# 535th game : win
# 536th game : loss
# 537th game : loss
# 538th game : loss
# 539th game : loss
# 540th game : loss
# 541th game : win
# 542th game : loss
# 543th game : loss
# 544th game : loss
# 545th game : loss
# 546th game : loss
# 547th game : loss
# 548th game : win
# 549th game : loss
# 550th game : loss
# 551th game : win
# 552th game : loss
# 553th game : loss
# 554th game : win
# 555th game : loss
# 556th game : loss
# 557th game : loss
# 558th game : loss
# 559th game : win
# 560th game : loss
# 561th game : win
# 562th game : loss
# 563th game : loss
# 564th game : loss
# 565th game : draw
# 566th game : win
# 567th game : loss
# 568th game : loss
# 569th game : loss
# 570th game : loss
# 571th game : loss
# 572th game : win
# 573th game : win
# 574th game : loss
# 575th game : loss
# 576th game : win
# 577th game : loss
# 578th game : draw
# 579th game : draw
# 580th game : win
# 581th game : loss
# 582th game : win
# 583th game : loss
# 584th game : loss
# 585th game : win
# 586th game : loss
# 587th game : win
# 588th game : loss
# 589th game : win
# 590th game : loss
# 591th game : loss
# 592th game : loss
# 593th game : loss
# 594th game : loss
# 595th game : draw
# 596th game : win
# 597th game : loss
# 598th game : loss
# 599th game : win
# 600th game : loss
# 601th game : draw
# 602th game : win
# 603th game : win
# 604th game : loss
# 605th game : win
# 606th game : win
# 607th game : loss
# 608th game : loss
# 609th game : draw
# 610th game : loss
# 611th game : loss
# 612th game : loss
# 613th game : loss
# 614th game : win
# 615th game : loss
# 616th game : win
# 617th game : win
# 618th game : loss
# 619th game : win
# 620th game : win
# 621th game : win
# 622th game : loss
# 623th game : loss
# 624th game : win
# 625th game : loss
# 626th game : draw
# 627th game : win
# 628th game : loss
# 629th game : win
# 630th game : win
# 631th game : win
# 632th game : draw
# 633th game : loss
# 634th game : loss
# 635th game : loss
# 636th game : win
# 637th game : win
# 638th game : win
# 639th game : win
# 640th game : loss
# 641th game : win
# 642th game : loss
# 643th game : loss
# 644th game : win
# 645th game : loss
# 646th game : loss
# 647th game : win
# 648th game : win
# 649th game : win
# 650th game : win
# 651th game : win
# 652th game : win
# 653th game : loss
# 654th game : draw
# 655th game : loss
# 656th game : loss
# 657th game : loss
# 658th game : draw
# 659th game : draw
# 660th game : loss
# 661th game : win
# 662th game : loss
# 663th game : loss
# 664th game : loss
# 665th game : loss
# 666th game : loss
# 667th game : loss
# 668th game : loss
# 669th game : loss
# 670th game : win
# 671th game : loss
# 672th game : win
# 673th game : loss
# 674th game : win
# 675th game : loss
# 676th game : loss
# 677th game : win
# 678th game : loss
# 679th game : win
# 680th game : loss
# 681th game : win
# 682th game : win
# 683th game : loss
# 684th game : win
# 685th game : win
# 686th game : win
# 687th game : win
# 688th game : draw
# 689th game : win
# 690th game : loss
# 691th game : loss
# 692th game : loss
# 693th game : win
# 694th game : loss
# 695th game : win
# 696th game : draw
# 697th game : loss
# 698th game : win
# 699th game : loss
# 700th game : loss
# 701th game : draw
# 702th game : win
# 703th game : win
# 704th game : loss
# 705th game : loss
# 706th game : loss
# 707th game : loss
# 708th game : loss
# 709th game : loss
# 710th game : loss
# 711th game : loss
# 712th game : win
# 713th game : win
# 714th game : draw
# 715th game : loss
# 716th game : loss
# 717th game : win
# 718th game : loss
# 719th game : loss
# 720th game : loss
# 721th game : loss
# 722th game : win
# 723th game : loss
# 724th game : loss
# 725th game : loss
# 726th game : loss
# 727th game : win
# 728th game : draw
# 729th game : loss
# 730th game : loss
# 731th game : loss
# 732th game : loss
# 733th game : loss
# 734th game : win
# 735th game : loss
# 736th game : win
# 737th game : win
# 738th game : loss
# 739th game : win
# 740th game : win
# 741th game : loss
# 742th game : win
# 743th game : loss
# 744th game : loss
# 745th game : loss
# 746th game : win
# 747th game : loss
# 748th game : win
# 749th game : loss
# 750th game : loss
# 751th game : loss
# 752th game : draw
# 753th game : loss
# 754th game : loss
# 755th game : loss
# 756th game : draw
# 757th game : loss
# 758th game : loss
# 759th game : draw
# 760th game : draw
# 761th game : loss
# 762th game : loss
# 763th game : loss
# 764th game : loss
# 765th game : loss
# 766th game : loss
# 767th game : win
# 768th game : loss
# 769th game : loss
# 770th game : draw
# 771th game : win
# 772th game : loss
# 773th game : loss
# 774th game : loss
# 775th game : loss
# 776th game : win
# 777th game : loss
# 778th game : win
# 779th game : win
# 780th game : win
# 781th game : loss
# 782th game : win
# 783th game : loss
# 784th game : loss
# 785th game : win
# 786th game : win
# 787th game : win
# 788th game : loss
# 789th game : win
# 790th game : loss
# 791th game : win
# 792th game : loss
# 793th game : loss
# 794th game : loss
# 795th game : loss
# 796th game : win
# 797th game : loss
# 798th game : loss
# 799th game : win
# 800th game : win
# 801th game : loss
# 802th game : loss
# 803th game : win
# 804th game : loss
# 805th game : loss
# 806th game : loss
# 807th game : loss
# 808th game : loss
# 809th game : loss
# 810th game : loss
# 811th game : win
# 812th game : loss
# 813th game : win
# 814th game : loss
# 815th game : win
# 816th game : win
# 817th game : draw
# 818th game : loss
# 819th game : win
# 820th game : win
# 821th game : loss
# 822th game : loss
# 823th game : loss
# 824th game : win
# 825th game : loss
# 826th game : loss
# 827th game : draw
# 828th game : loss
# 829th game : loss
# 830th game : loss
# 831th game : loss
# 832th game : loss
# 833th game : loss
# 834th game : win
# 835th game : loss
# 836th game : loss
# 837th game : draw
# 838th game : loss
# 839th game : loss
# 840th game : loss
# 841th game : loss
# 842th game : win
# 843th game : loss
# 844th game : loss
# 845th game : loss
# 846th game : loss
# 847th game : loss
# 848th game : draw
# 849th game : loss
# 850th game : loss
# 851th game : loss
# 852th game : loss
# 853th game : loss
# 854th game : loss
# 855th game : loss
# 856th game : loss
# 857th game : win
# 858th game : loss
# 859th game : loss
# 860th game : win
# 861th game : loss
# 862th game : win
# 863th game : win
# 864th game : loss
# 865th game : loss
# 866th game : loss
# 867th game : loss
# 868th game : loss
# 869th game : loss
# 870th game : win
# 871th game : loss
# 872th game : win
# 873th game : win
# 874th game : win
# 875th game : win
# 876th game : win
# 877th game : win
# 878th game : win
# 879th game : loss
# 880th game : loss
# 881th game : loss
# 882th game : loss
# 883th game : loss
# 884th game : loss
# 885th game : loss
# 886th game : loss
# 887th game : loss
# 888th game : win
# 889th game : loss
# 890th game : loss
# 891th game : loss
# 892th game : win
# 893th game : loss
# 894th game : loss
# 895th game : win
# 896th game : draw
# 897th game : win
# 898th game : loss
# 899th game : loss
# 900th game : loss
# 901th game : loss
# 902th game : loss
# 903th game : win
# 904th game : loss
# 905th game : loss
# 906th game : loss
# 907th game : loss
# 908th game : win
# 909th game : win
# 910th game : win
# 911th game : win
# 912th game : loss
# 913th game : win
# 914th game : win
# 915th game : loss
# 916th game : loss
# 917th game : loss
# 918th game : loss
# 919th game : win
# 920th game : win
# 921th game : win
# 922th game : loss
# 923th game : loss
# 924th game : loss
# 925th game : loss
# 926th game : loss
# 927th game : loss
# 928th game : loss
# 929th game : win
# 930th game : loss
# 931th game : win
# 932th game : win
# 933th game : loss
# 934th game : loss
# 935th game : loss
# 936th game : loss
# 937th game : loss
# 938th game : win
# 939th game : loss
# 940th game : loss
# 941th game : loss
# 942th game : loss
# 943th game : loss
# 944th game : loss
# 945th game : loss
# 946th game : win
# 947th game : loss
# 948th game : win
# 949th game : win
# 950th game : loss
# 951th game : loss
# 952th game : win
# 953th game : win
# 954th game : loss
# 955th game : win
# 956th game : loss
# 957th game : loss
# 958th game : win
# 959th game : win
# 960th game : draw
# 961th game : win
# 962th game : loss
# 963th game : loss
# 964th game : loss
# 965th game : loss
# 966th game : win
# 967th game : loss
# 968th game : loss
# 969th game : loss
# 970th game : loss
# 971th game : draw
# 972th game : win
# 973th game : loss
# 974th game : loss
# 975th game : loss
# 976th game : draw
# 977th game : loss
# 978th game : loss
# 979th game : win
# 980th game : loss
# 981th game : loss
# 982th game : loss
# 983th game : loss
# 984th game : loss
# 985th game : loss
# 986th game : win
# 987th game : loss
# 988th game : win
# 989th game : win
# 990th game : loss
# 991th game : win
# 992th game : win
# 993th game : win
# 994th game : win
# 995th game : win
# 996th game : loss
# 997th game : draw
# 998th game : win
# 999th game : draw
# 1000th game : win

# %% [markdown]
# ### 플레이어의 승률을 계산

# %%
score = total_win/(total_win + total_loss)
print("플레이어의 게임 승률 = %f" %score)
# Out:
# 플레이어의 게임 승률 = 0.338314

# %% [markdown]
# ### 플레이어의 소지금 변화를 그래프로 시각화

# %%
from matplotlib import pyplot as plt

plt.plot(have_money)
plt.show()

# %% [markdown]
# ## 플레이어의 승률 높이기
# State를 수정하여 승률이 더 높은 policy를 찾기
#
#  - 딜러는 게임이 끝났을 때, 남은 카드의 수를 확인
#  - 15장 이상이라면 해당 덱을 다음 게임에서 그대로 사용
#  - 15장 미만이라면 52장의 셔플된 새로운 카드를 기존 덱에 추가

# %%
money = 10000 # 초기 자금
have_money = [] # 매 게임 별 플레이어의 소지금 변화 기록

total_win = 0
total_loss = 0
total_draw = 0

card_counting = 0

for i in range(1000): # 1000번의 게임 진행
    money -= 10 # 게임 참가비 지불
    episode = mc_es.generate_episode(dealer, agent, deck) # 에피소드 반환

    if episode[-1][-1] == 1: # 승리
        total_win += 1 # 카운트 증가
        money += 20 # 20달러 획득
        print("%.fth game : win" %(i+1)) # 게임 결과 출력 
    elif episode[-1][-1] == 0: # 무승부
        total_draw += 1
        money += 10 # 10달러 획득
        print("%.fth game : draw" %(i+1))
    else: # 패배
        total_loss += 1
        money += 0 # 0달러 획득
        print("%.fth game : loss" %(i+1))

    have_money.append(money) # 해당 게임 결과에 따른 소지금 기록
# Out:
# 1th game : loss
# 2th game : win
# 3th game : draw
# 4th game : loss
# 5th game : win
# 6th game : loss
# 7th game : loss
# 8th game : loss
# 9th game : loss
# 10th game : loss
# 11th game : draw
# 12th game : win
# 13th game : loss
# 14th game : loss
# 15th game : loss
# 16th game : loss
# 17th game : loss
# 18th game : loss
# 19th game : loss
# 20th game : loss
# 21th game : win
# 22th game : loss
# 23th game : win
# 24th game : loss
# 25th game : loss
# 26th game : draw
# 27th game : loss
# 28th game : loss
# 29th game : loss
# 30th game : win
# 31th game : win
# 32th game : win
# 33th game : loss
# 34th game : draw
# 35th game : loss
# 36th game : win
# 37th game : loss
# 38th game : win
# 39th game : loss
# 40th game : loss
# 41th game : win
# 42th game : loss
# 43th game : loss
# 44th game : win
# 45th game : loss
# 46th game : win
# 47th game : win
# 48th game : loss
# 49th game : win
# 50th game : loss
# 51th game : win
# 52th game : win
# 53th game : loss
# 54th game : win
# 55th game : loss
# 56th game : loss
# 57th game : win
# 58th game : loss
# 59th game : win
# 60th game : loss
# 61th game : loss
# 62th game : loss
# 63th game : loss
# 64th game : loss
# 65th game : loss
# 66th game : loss
# 67th game : win
# 68th game : loss
# 69th game : loss
# 70th game : win
# 71th game : loss
# 72th game : loss
# 73th game : win
# 74th game : win
# 75th game : loss
# 76th game : loss
# 77th game : loss
# 78th game : loss
# 79th game : win
# 80th game : loss
# 81th game : win
# 82th game : loss
# 83th game : loss
# 84th game : win
# 85th game : loss
# 86th game : loss
# 87th game : loss
# 88th game : loss
# 89th game : win
# 90th game : loss
# 91th game : loss
# 92th game : loss
# 93th game : win
# 94th game : draw
# 95th game : win
# 96th game : loss
# 97th game : loss
# 98th game : win
# 99th game : loss
# 100th game : loss
# 101th game : win
# 102th game : win
# 103th game : win
# 104th game : loss
# 105th game : loss
# 106th game : loss
# 107th game : win
# 108th game : loss
# 109th game : loss
# 110th game : loss
# 111th game : loss
# 112th game : win
# 113th game : win
# 114th game : draw
# 115th game : loss
# 116th game : loss
# 117th game : loss
# 118th game : loss
# 119th game : loss
# 120th game : loss
# 121th game : loss
# 122th game : loss
# 123th game : win
# 124th game : draw
# 125th game : win
# 126th game : loss
# 127th game : loss
# 128th game : loss
# 129th game : loss
# 130th game : draw
# 131th game : loss
# 132th game : loss
# 133th game : loss
# 134th game : win
# 135th game : loss
# 136th game : loss
# 137th game : loss
# 138th game : loss
# 139th game : win
# 140th game : loss
# 141th game : loss
# 142th game : loss
# 143th game : loss
# 144th game : loss
# 145th game : loss
# 146th game : loss
# 147th game : win
# 148th game : loss
# 149th game : loss
# 150th game : win
# 151th game : win
# 152th game : win
# 153th game : win
# 154th game : loss
# 155th game : loss
# 156th game : win
# 157th game : loss
# 158th game : draw
# 159th game : win
# 160th game : win
# 161th game : loss
# 162th game : win
# 163th game : loss
# 164th game : loss
# 165th game : draw
# 166th game : win
# 167th game : loss
# 168th game : draw
# 169th game : win
# 170th game : win
# 171th game : loss
# 172th game : win
# 173th game : loss
# 174th game : loss
# 175th game : loss
# 176th game : win
# 177th game : loss
# 178th game : win
# 179th game : loss
# 180th game : win
# 181th game : loss
# 182th game : loss
# 183th game : loss
# 184th game : win
# 185th game : win
# 186th game : draw
# 187th game : win
# 188th game : loss
# 189th game : loss
# 190th game : win
# 191th game : win
# 192th game : win
# 193th game : loss
# 194th game : win
# 195th game : draw
# 196th game : win
# 197th game : loss
# 198th game : loss
# 199th game : loss
# 200th game : loss
# 201th game : win
# 202th game : loss
# 203th game : loss
# 204th game : win
# 205th game : win
# 206th game : loss
# 207th game : loss
# 208th game : win
# 209th game : loss
# 210th game : win
# 211th game : loss
# 212th game : loss
# 213th game : win
# 214th game : loss
# 215th game : loss
# 216th game : loss
# 217th game : win
# 218th game : loss
# 219th game : loss
# 220th game : loss
# 221th game : loss
# 222th game : loss
# 223th game : loss
# 224th game : win
# 225th game : loss
# 226th game : loss
# 227th game : loss
# 228th game : loss
# 229th game : loss
# 230th game : win
# 231th game : win
# 232th game : loss
# 233th game : loss
# 234th game : loss
# 235th game : win
# 236th game : win
# 237th game : loss
# 238th game : win
# 239th game : loss
# 240th game : win
# 241th game : win
# 242th game : win
# 243th game : win
# 244th game : loss
# 245th game : loss
# 246th game : loss
# 247th game : loss
# 248th game : win
# 249th game : win
# 250th game : loss
# 251th game : win
# 252th game : loss
# 253th game : loss
# 254th game : loss
# 255th game : loss
# 256th game : loss
# 257th game : win
# 258th game : loss
# 259th game : win
# 260th game : loss
# 261th game : loss
# 262th game : loss
# 263th game : win
# 264th game : draw
# 265th game : loss
# 266th game : loss
# 267th game : loss
# 268th game : loss
# 269th game : loss
# 270th game : win
# 271th game : win
# 272th game : loss
# 273th game : loss
# 274th game : loss
# 275th game : loss
# 276th game : loss
# 277th game : loss
# 278th game : loss
# 279th game : draw
# 280th game : loss
# 281th game : loss
# 282th game : win
# 283th game : loss
# 284th game : win
# 285th game : loss
# 286th game : win
# 287th game : win
# 288th game : loss
# 289th game : draw
# 290th game : loss
# 291th game : loss
# 292th game : draw
# 293th game : loss
# 294th game : loss
# 295th game : loss
# 296th game : loss
# 297th game : loss
# 298th game : win
# 299th game : loss
# 300th game : loss
# 301th game : draw
# 302th game : loss
# 303th game : win
# 304th game : loss
# 305th game : loss
# 306th game : loss
# 307th game : loss
# 308th game : win
# 309th game : loss
# 310th game : draw
# 311th game : win
# 312th game : win
# 313th game : loss
# 314th game : win
# 315th game : win
# 316th game : loss
# 317th game : win
# 318th game : win
# 319th game : loss
# 320th game : loss
# 321th game : win
# 322th game : loss
# 323th game : loss
# 324th game : win
# 325th game : loss
# 326th game : loss
# 327th game : loss
# 328th game : draw
# 329th game : win
# 330th game : loss
# 331th game : draw
# 332th game : loss
# 333th game : win
# 334th game : loss
# 335th game : loss
# 336th game : win
# 337th game : draw
# 338th game : win
# 339th game : loss
# 340th game : loss
# 341th game : loss
# 342th game : win
# 343th game : loss
# 344th game : win
# 345th game : loss
# 346th game : win
# 347th game : win
# 348th game : loss
# 349th game : win
# 350th game : win
# 351th game : loss
# 352th game : loss
# 353th game : loss
# 354th game : win
# 355th game : win
# 356th game : win
# 357th game : draw
# 358th game : loss
# 359th game : loss
# 360th game : loss
# 361th game : win
# 362th game : win
# 363th game : loss
# 364th game : loss
# 365th game : draw
# 366th game : win
# 367th game : win
# 368th game : loss
# 369th game : loss
# 370th game : loss
# 371th game : loss
# 372th game : loss
# 373th game : loss
# 374th game : loss
# 375th game : win
# 376th game : draw
# 377th game : loss
# 378th game : loss
# 379th game : loss
# 380th game : loss
# 381th game : loss
# 382th game : loss
# 383th game : loss
# 384th game : loss
# 385th game : loss
# 386th game : loss
# 387th game : win
# 388th game : loss
# 389th game : loss
# 390th game : loss
# 391th game : win
# 392th game : loss
# 393th game : win
# 394th game : win
# 395th game : loss
# 396th game : loss
# 397th game : loss
# 398th game : win
# 399th game : loss
# 400th game : loss
# 401th game : loss
# 402th game : loss
# 403th game : loss
# 404th game : win
# 405th game : win
# 406th game : loss
# 407th game : win
# 408th game : win
# 409th game : win
# 410th game : loss
# 411th game : win
# 412th game : loss
# 413th game : win
# 414th game : win
# 415th game : loss
# 416th game : win
# 417th game : loss
# 418th game : loss
# 419th game : win
# 420th game : loss
# 421th game : win
# 422th game : win
# 423th game : loss
# 424th game : draw
# 425th game : loss
# 426th game : loss
# 427th game : loss
# 428th game : loss
# 429th game : win
# 430th game : loss
# 431th game : win
# 432th game : loss
# 433th game : win
# 434th game : loss
# 435th game : loss
# 436th game : win
# 437th game : loss
# 438th game : loss
# 439th game : win
# 440th game : win
# 441th game : win
# 442th game : loss
# 443th game : loss
# 444th game : win
# 445th game : draw
# 446th game : loss
# 447th game : loss
# 448th game : loss
# 449th game : loss
# 450th game : loss
# 451th game : loss
# 452th game : loss
# 453th game : win
# 454th game : win
# 455th game : win
# 456th game : win
# 457th game : loss
# 458th game : draw
# 459th game : loss
# 460th game : win
# 461th game : win
# 462th game : loss
# 463th game : loss
# 464th game : loss
# 465th game : draw
# 466th game : win
# 467th game : loss
# 468th game : loss
# 469th game : loss
# 470th game : loss
# 471th game : win
# 472th game : win
# 473th game : win
# 474th game : loss
# 475th game : loss
# 476th game : loss
# 477th game : win
# 478th game : loss
# 479th game : win
# 480th game : loss
# 481th game : loss
# 482th game : win
# 483th game : win
# 484th game : win
# 485th game : loss
# 486th game : loss
# 487th game : loss
# 488th game : loss
# 489th game : loss
# 490th game : loss
# 491th game : win
# 492th game : loss
# 493th game : loss
# 494th game : win
# 495th game : loss
# 496th game : loss
# 497th game : win
# 498th game : win
# 499th game : win
# 500th game : win
# 501th game : loss
# 502th game : loss
# 503th game : loss
# 504th game : loss
# 505th game : loss
# 506th game : win
# 507th game : win
# 508th game : win
# 509th game : win
# 510th game : loss
# 511th game : loss
# 512th game : draw
# 513th game : win
# 514th game : draw
# 515th game : loss
# 516th game : win
# 517th game : loss
# 518th game : win
# 519th game : loss
# 520th game : win
# 521th game : win
# 522th game : loss
# 523th game : win
# 524th game : loss
# 525th game : win
# 526th game : loss
# 527th game : loss
# 528th game : loss
# 529th game : loss
# 530th game : loss
# 531th game : loss
# 532th game : loss
# 533th game : loss
# 534th game : loss
# 535th game : win
# 536th game : loss
# 537th game : loss
# 538th game : loss
# 539th game : loss
# 540th game : loss
# 541th game : loss
# 542th game : loss
# 543th game : win
# 544th game : win
# 545th game : loss
# 546th game : win
# 547th game : loss
# 548th game : win
# 549th game : loss
# 550th game : win
# 551th game : draw
# 552th game : win
# 553th game : loss
# 554th game : win
# 555th game : draw
# 556th game : draw
# 557th game : win
# 558th game : win
# 559th game : win
# 560th game : win
# 561th game : loss
# 562th game : loss
# 563th game : loss
# 564th game : loss
# 565th game : loss
# 566th game : draw
# 567th game : loss
# 568th game : win
# 569th game : loss
# 570th game : loss
# 571th game : loss
# 572th game : win
# 573th game : loss
# 574th game : win
# 575th game : loss
# 576th game : win
# 577th game : loss
# 578th game : loss
# 579th game : loss
# 580th game : win
# 581th game : draw
# 582th game : loss
# 583th game : win
# 584th game : draw
# 585th game : loss
# 586th game : loss
# 587th game : loss
# 588th game : draw
# 589th game : draw
# 590th game : win
# 591th game : loss
# 592th game : win
# 593th game : win
# 594th game : loss
# 595th game : loss
# 596th game : win
# 597th game : loss
# 598th game : loss
# 599th game : win
# 600th game : loss
# 601th game : loss
# 602th game : loss
# 603th game : loss
# 604th game : loss
# 605th game : win
# 606th game : loss
# 607th game : win
# 608th game : win
# 609th game : loss
# 610th game : loss
# 611th game : win
# 612th game : win
# 613th game : loss
# 614th game : draw
# 615th game : win
# 616th game : win
# 617th game : loss
# 618th game : draw
# 619th game : win
# 620th game : loss
# 621th game : loss
# 622th game : loss
# 623th game : win
# 624th game : loss
# 625th game : loss
# 626th game : draw
# 627th game : win
# 628th game : win
# 629th game : loss
# 630th game : loss
# 631th game : win
# 632th game : loss
# 633th game : loss
# 634th game : loss
# 635th game : loss
# 636th game : loss
# 637th game : loss
# 638th game : loss
# 639th game : win
# 640th game : loss
# 641th game : loss
# 642th game : loss
# 643th game : win
# 644th game : loss
# 645th game : loss
# 646th game : win
# 647th game : win
# 648th game : draw
# 649th game : win
# 650th game : loss
# 651th game : loss
# 652th game : loss
# 653th game : loss
# 654th game : loss
# 655th game : win
# 656th game : win
# 657th game : win
# 658th game : loss
# 659th game : win
# 660th game : win
# 661th game : win
# 662th game : loss
# 663th game : loss
# 664th game : win
# 665th game : loss
# 666th game : loss
# 667th game : win
# 668th game : loss
# 669th game : loss
# 670th game : win
# 671th game : loss
# 672th game : win
# 673th game : loss
# 674th game : win
# 675th game : win
# 676th game : loss
# 677th game : win
# 678th game : loss
# 679th game : loss
# 680th game : win
# 681th game : loss
# 682th game : win
# 683th game : win
# 684th game : win
# 685th game : win
# 686th game : loss
# 687th game : loss
# 688th game : win
# 689th game : loss
# 690th game : win
# 691th game : loss
# 692th game : loss
# 693th game : loss
# 694th game : loss
# 695th game : win
# 696th game : win
# 697th game : loss
# 698th game : win
# 699th game : loss
# 700th game : win
# 701th game : loss
# 702th game : draw
# 703th game : win
# 704th game : win
# 705th game : loss
# 706th game : draw
# 707th game : loss
# 708th game : win
# 709th game : loss
# 710th game : loss
# 711th game : win
# 712th game : loss
# 713th game : loss
# 714th game : loss
# 715th game : win
# 716th game : loss
# 717th game : win
# 718th game : loss
# 719th game : loss
# 720th game : win
# 721th game : win
# 722th game : loss
# 723th game : loss
# 724th game : win
# 725th game : loss
# 726th game : loss
# 727th game : loss
# 728th game : loss
# 729th game : loss
# 730th game : loss
# 731th game : win
# 732th game : loss
# 733th game : win
# 734th game : loss
# 735th game : loss
# 736th game : loss
# 737th game : win
# 738th game : loss
# 739th game : win
# 740th game : loss
# 741th game : win
# 742th game : win
# 743th game : loss
# 744th game : loss
# 745th game : win
# 746th game : draw
# 747th game : loss
# 748th game : loss
# 749th game : loss
# 750th game : win
# 751th game : loss
# 752th game : win
# 753th game : loss
# 754th game : win
# 755th game : loss
# 756th game : loss
# 757th game : loss
# 758th game : loss
# 759th game : loss
# 760th game : loss
# 761th game : win
# 762th game : loss
# 763th game : loss
# 764th game : win
# 765th game : draw
# 766th game : loss
# 767th game : loss
# 768th game : loss
# 769th game : win
# 770th game : loss
# 771th game : win
# 772th game : loss
# 773th game : loss
# 774th game : win
# 775th game : win
# 776th game : loss
# 777th game : loss
# 778th game : loss
# 779th game : win
# 780th game : loss
# 781th game : win
# 782th game : win
# 783th game : win
# 784th game : loss
# 785th game : loss
# 786th game : loss
# 787th game : loss
# 788th game : draw
# 789th game : win
# 790th game : win
# 791th game : loss
# 792th game : loss
# 793th game : loss
# 794th game : loss
# 795th game : loss
# 796th game : win
# 797th game : loss
# 798th game : loss
# 799th game : draw
# 800th game : win
# 801th game : loss
# 802th game : win
# 803th game : win
# 804th game : loss
# 805th game : loss
# 806th game : win
# 807th game : loss
# 808th game : loss
# 809th game : win
# 810th game : loss
# 811th game : win
# 812th game : win
# 813th game : loss
# 814th game : win
# 815th game : loss
# 816th game : win
# 817th game : loss
# 818th game : loss
# 819th game : win
# 820th game : win
# 821th game : win
# 822th game : loss
# 823th game : win
# 824th game : win
# 825th game : draw
# 826th game : loss
# 827th game : loss
# 828th game : loss
# 829th game : loss
# 830th game : loss
# 831th game : win
# 832th game : loss
# 833th game : win
# 834th game : win
# 835th game : loss
# 836th game : loss
# 837th game : win
# 838th game : loss
# 839th game : loss
# 840th game : win
# 841th game : win
# 842th game : win
# 843th game : loss
# 844th game : loss
# 845th game : win
# 846th game : loss
# 847th game : loss
# 848th game : win
# 849th game : loss
# 850th game : loss
# 851th game : loss
# 852th game : loss
# 853th game : draw
# 854th game : win
# 855th game : loss
# 856th game : loss
# 857th game : draw
# 858th game : loss
# 859th game : loss
# 860th game : win
# 861th game : win
# 862th game : loss
# 863th game : loss
# 864th game : win
# 865th game : loss
# 866th game : win
# 867th game : win
# 868th game : loss
# 869th game : win
# 870th game : draw
# 871th game : win
# 872th game : loss
# 873th game : win
# 874th game : loss
# 875th game : win
# 876th game : win
# 877th game : loss
# 878th game : win
# 879th game : win
# 880th game : loss
# 881th game : loss
# 882th game : loss
# 883th game : loss
# 884th game : win
# 885th game : draw
# 886th game : loss
# 887th game : win
# 888th game : loss
# 889th game : win
# 890th game : win
# 891th game : win
# 892th game : win
# 893th game : win
# 894th game : loss
# 895th game : win
# 896th game : loss
# 897th game : win
# 898th game : loss
# 899th game : win
# 900th game : loss
# 901th game : loss
# 902th game : win
# 903th game : loss
# 904th game : win
# 905th game : loss
# 906th game : loss
# 907th game : loss
# 908th game : win
# 909th game : loss
# 910th game : win
# 911th game : loss
# 912th game : loss
# 913th game : loss
# 914th game : loss
# 915th game : win
# 916th game : win
# 917th game : win
# 918th game : loss
# 919th game : loss
# 920th game : loss
# 921th game : win
# 922th game : loss
# 923th game : loss
# 924th game : draw
# 925th game : loss
# 926th game : loss
# 927th game : loss
# 928th game : loss
# 929th game : draw
# 930th game : loss
# 931th game : win
# 932th game : loss
# 933th game : loss
# 934th game : draw
# 935th game : loss
# 936th game : loss
# 937th game : loss
# 938th game : loss
# 939th game : win
# 940th game : loss
# 941th game : win
# 942th game : win
# 943th game : loss
# 944th game : loss
# 945th game : loss
# 946th game : draw
# 947th game : loss
# 948th game : loss
# 949th game : win
# 950th game : win
# 951th game : loss
# 952th game : loss
# 953th game : loss
# 954th game : loss
# 955th game : loss
# 956th game : loss
# 957th game : win
# 958th game : win
# 959th game : win
# 960th game : win
# 961th game : win
# 962th game : loss
# 963th game : loss
# 964th game : win
# 965th game : win
# 966th game : draw
# 967th game : win
# 968th game : loss
# 969th game : loss
# 970th game : draw
# 971th game : win
# 972th game : win
# 973th game : loss
# 974th game : loss
# 975th game : win
# 976th game : win
# 977th game : win
# 978th game : loss
# 979th game : loss
# 980th game : loss
# 981th game : win
# 982th game : win
# 983th game : loss
# 984th game : loss
# 985th game : win
# 986th game : loss
# 987th game : loss
# 988th game : win
# 989th game : win
# 990th game : win
# 991th game : loss
# 992th game : loss
# 993th game : win
# 994th game : loss
# 995th game : loss
# 996th game : loss
# 997th game : win
# 998th game : win
# 999th game : loss
# 1000th game : loss

# %%
score = total_win/(total_win + total_loss)
print("코드 수정 시 플레이어의 게임 승률 = %f" %score)
# Out:
# 코드 수정 시 플레이어의 게임 승률 = 0.380851

# %%
from matplotlib import pyplot as plt

plt.plot(have_money)
plt.show()

# %% [markdown]
# ---
# ### 참고자료
# [1] Reinforcement Learning - An Introduction (Richard S. Sutton, Andreow G. Barto), 2nd edition, p.120-124 https://web.stanford.edu/class/psych209/Readings/SuttonBartoIPRLBook2ndEd.pdf <br>
# [2] matplotlib.pyplot.plot Documentation, https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html <br>
# [3] matplotlib.pyplot.plot Examples https://matplotlib.org/tutorials/introductory/pyplot.html
